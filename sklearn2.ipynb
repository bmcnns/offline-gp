# %%
from dataset import load_dataset
from sklearn.preprocessing import StandardScaler
from pyoperon.sklearn import SymbolicRegressor
import os
import pickle

# %%
parameters = {
                'allowed_symbols': 'add,sub,mul,div,fmin,fmax,pow,ceil,floor,exp,cos,sin,constant,variable',
                'offspring_generator': 'basic',
                'reinserter': 'keep-best',
                'n_threads': 16,
                'optimizer_iterations': 1,
                'objectives': ['mse', 'r2'],
                'tournament_size': 3,
                'generations': 100,
                'warm_start': True,
            }
X, y = load_dataset("Minimal-Hopper-Expert-v5")
y = y[:, 0]   

model = SymbolicRegressor(**parameters)

model.fit(X, y)
# Out:
# SymbolicRegressor(allowed_symbols='add,sub,mul,div,fmin,fmax,pow,ceil,floor,exp,cos,sin,constant,variable',
#                   generations=100, max_time=9223372036854775807, n_threads=16,
#                   objectives=['mse', 'r2'], optimizer_iterations=1,
#                   pool_size=1000, random_state=13388371087513410152,
#                   tournament_size=3, warm_start=True)

# %%
model.get_model_string(model.model_)
# Out:
# '(0.001 + (0.968 * ((((((-0.384) * X8) - (0.065 * X10)) + (((((-0.323) * X3) - ((((-0.000) * X11) + ((-0.014) * X7)) + ((-0.022) * X11))) * (cos(((-4.184) * X5)) + (((3.334 * X8) - 5.729) * (0.186 * X3)))) * ((-2.177) * X7))) + exp(((0.106 * X8) - (cos(((-2.038) * X5)) + (0.047 * X11))))) + (((exp(((0.322 * X7) + sin(cos(((-1.679) * X5))))) - (sin(((7.898 * X2) - (((-1.342) * X3) - ((-0.143) * X11)))) - (0.203 * X6))) + ((-0.594) * X7)) - 3.524))))'

# %%
model.fit(X, y)
# Out:
# SymbolicRegressor(allowed_symbols='add,sub,mul,div,fmin,fmax,pow,ceil,floor,exp,cos,sin,constant,variable',
#                   generations=100, max_time=9223372036854775807, n_threads=16,
#                   objectives=['mse', 'r2'], optimizer_iterations=1,
#                   pool_size=1000, random_state=13388371087513410152,
#                   tournament_size=3, warm_start=True)

# %%
model.get_model_string(model.model_)
# Out:
# '((-0.000) + (0.992 * ((((min((((-0.304) * X8) + ((-0.068) * X10)), ((-6.770) * X3))) + ((((0.015 * X7) - ((0.505 * X2) - (((-0.274) * X3) - ((-0.021) * X11)))) * (cos(((-4.210) * X5)) + (((3.874 * X8) - 6.283) * (0.195 * X3)))) * ((-2.177) * X7))) + (((0.336 * X3) - (0.032 * X11)) - cos(((-1.455) * X5)))) + (((exp(((0.296 * X7) + cos(((-1.311) * X5)))) - (sin(((7.470 * X2) - (((-1.302) * X3) - ((-0.137) * X11)))) - (0.148 * X6))) + ((-0.645) * X7)) - 2.198))))'
